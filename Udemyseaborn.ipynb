# %%
import seaborn as sns
import pandas as pd
# %matplotlib inline
import pl

# %%
tip = pd.read_csv('tips.csv')
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # joint plot

# %%
sns.jointplot(x='total_bill',y='tip',data=tip ,kind="hex")

# %%
sns.jointplot(x='total_bill',y='tip',data=tip ,kind="kde")

# %%
sns.jointplot(x='total_bill',y='tip',data=tip,kind='reg')

# %% [markdown]
# # pairplot

# %%
sns.pairplot(tip ,hue='time')

# %%
sns.pairplot(tip ,hue='sex')

# %%
sns.pairplot(tip ,hue='smoker')

# %%
sns.rugplot(tip['tip'])
# Out:
# <AxesSubplot:xlabel='tip'>

# %% [markdown]
# # catgorical plots

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # barplot

# %%
import numpy as np

# %%
sns.barplot(x='smoker',y='total_bill',data=tip,estimator =np.std )
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='total_bill'>

# %%
sns.countplot(x="smoker" ,data=tip)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x="day" ,data=tip)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %% [markdown]
# # boxplot

# %%
sns.boxplot(x='day',y='total_bill',data=tip,hue='smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # violin plot

# %%
sns.violinplot(x='day',y='total_bill',data=tip,hue='sex',split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',data=tip ,hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=tip)
sns.swarmplot(x='day',y='total_bill' ,data=tip)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # factorplot

# %% [markdown]
# this plot generalise plot you this plot you can plot any plot just changing  kind argument

# %%
sns.factorplot(x='day',y='total_bill',data=tip,kind='bar')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# # Matrix plot

# %%
 iris =pd.read_csv('iris.csv')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
 tc= tip.corr()

# %%
sns.heatmap(tc,annot =True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# heatmap is used find correlation between the  variable

# %%
sns.heatmap(tc,annot=True ,cmap ='coolwarm')
# Out:
# <AxesSubplot:>

# %%
ir=iris.corr()

# %%
sns.heatmap(ir,annot=True)
# Out:
# <AxesSubplot:>

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
ir1 = iris.pivot_table(index="species")

# %%
ir1
# Out:
#                  petal_length  petal_width  sepal_length  sepal_width
# species
# Iris-setosa             1.464        0.244         5.006        3.418
# Iris-versicolor         4.260        1.326         5.936        2.770
# Iris-virginica          5.552        2.026         6.588        2.974

# %%
sns.heatmap(ir1,annot=True)
# Out:
# <AxesSubplot:ylabel='species'>

# %% [markdown]
# # Clustermap

# %%
sns.clustermap(ir1,annot=True,cmap ='coolwarm')

# %% [markdown]
# it cluster the data based on similarity

# %%
sns.pairplot(iris)

# %%
import matplotlib.pyplot as plt
g =sns.PairGrid(iris)
g.map_diag(sns.histplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %%
g = sns.FacetGrid(data=tip,col='time',row='smoker' )
g.map(sns.histplot,'total_bill')

# %%
import matplotlib.pyplot as plt

g = sns.FacetGrid(data=tip,col='time',row='smoker' )
g.map(plt.scatter,'total_bill','tip')

# %% [markdown]
# # Regression plot

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill',y='tip',data=tip,hue='sex',markers=['o','v'],scatter_kws={'s':100})

# %%
sns.lmplot(x='total_bill',y='tip',data=tip,col='sex',row='time')

# %% [markdown]
# # Style color

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_style('darkgrid')
sns.countplot(x='sex',data=tip)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_style('ticks')
sns.countplot(x='sex',data=tip)
sns.despine(left=True,bottom=True)

# %%
plt.figure(figsize=(12,6))
sns.set_style('ticks')
sns.countplot(x='sex',data=tip)
sns.despine(left=True,bottom=True)

# %% [markdown]
# figsize used to set plot size and derpine is used remove horizontal and vertical line

# %%
sns.lmplot(data=tip,x="total_bill", y='tip',palette ='seismic' ,hue="sex")
